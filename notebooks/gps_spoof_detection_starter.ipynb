# %% [markdown]
# # GPS Spoofing Detection
# Prototype AI logic here.

# %%
import numpy as np
import matplotlib.pyplot as plt
gps = np.random.normal(0, 1, 100)
plt.plot(gps)
plt.title('Simulated GPS Signal')
plt.show()
